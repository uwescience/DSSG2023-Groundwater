# %%
import netCDF4 as nc
import pandas as pd
import os
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import collections
import matplotlib.font_manager
import xarray as xr
import statistics
import geodatasets
from shapely.geometry import shape, Point
import imageio
from IPython.display import Image
from pathos.multiprocessing import ProcessingPool as Pool
import plotly.express as px

plt.style.use('ggplot')

os.environ['HDF5_USE_FILE_LOCKING']='FALSE'

# %%
#Loading shapefile of CRB (comprising of 8 total regions, including Upper and Lower basin)
s = gpd.read_file("/home/kmk58/remoteData/CRB_SHAPEFILE/CRB_SHAPEFILE/Aqueduct_river_basins_COLORADO RIVER (PACIFIC OCEAN).shp")


# plot of entire Colorado River Basin
plt.figure(figsize=[10,10])
s.plot()
plt.title("Colorado River Basin")
plt.show()

# %%
#Read in GRACE mascon
df = xr.open_dataset("/home/kmk58/remoteData/GRACE_MASCON/data/TELLUS_GRAC-GRFO_MASCON_CRI_GRID_RL06.1_V3/GRCTellus.JPL.200204_202304.GLO.RL06.1M.MSCNv03CRI.nc")
# Out:
# /home/kmk58/.local/lib/python3.11/site-packages/xarray/backends/plugins.py:80: RuntimeWarning: Engine 'cfgrib' loading failed:
# Cannot find the ecCodes library
#   warnings.warn(f"Engine {name!r} loading failed:\n{ex}", RuntimeWarning)

# %%
fig = px.scatter_mapbox(u_grace_df_whole,
                        lat=u_grace_df_whole.lat,
                        lon=u_grace_df_whole.lon, color=u_grace_df_whole.SoilMoi0_10cm_inst,
                        zoom=3.75,animation_frame="time")
fig.update_layout(mapbox_style="carto-positron")
#fig.update_layout(mapbox_bounds={"west": -119, "east": -102, "south": 31, "north": 44})
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 fig = px.scatter_mapbox(u_grace_df_whole,
#       2                         lat=u_grace_df_whole.lat,
#       3                         lon=u_grace_df_whole.lon, color=u_grace_df_whole.SoilMoi0_10cm_inst,
#       4                         zoom=3.75,animation_frame="time")
#       5 fig.update_layout(mapbox_style="carto-positron")
#       6 #fig.update_layout(mapbox_bounds={"west": -119, "east": -102, "south": 31, "north": 44})
#
# NameError: name 'u_grace_df_whole' is not defined
