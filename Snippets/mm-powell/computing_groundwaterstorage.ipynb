# %%
import netCDF4 as nc
import pandas as pd
import os
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import collections
import matplotlib.font_manager
import xarray as xr
import statistics
import geodatasets

# %%
# !pwd
# Out:
# /home/maiampow/code

# %% [markdown]
# ## NLDAS Data

# %%
# Defining path to GLDAS_NOAH10_M data
p = "/home/maiampow/remoteData/GLDAS_NEW/GLDAS_NOAH10_M/"

# %%
# Creating dataframe for only Mississippi Basin 

miss_region_df = pd.DataFrame()

#Iterating through files in path
for filename in os.listdir(p):
    try:
        #Reading in data as xarray then converting to DataFrame
        xd = xr.open_dataset(p+str(filename))
        xd_df = xd.to_dataframe()
        xd_df.reset_index(inplace=True)
        
        #Extracting only needed columns 
        int_df = xd_df[["time", "lon", "lat", "SWE_inst", 'SoilMoi0_10cm_inst',
           'SoilMoi10_40cm_inst', 'SoilMoi40_100cm_inst', 'SoilMoi100_200cm_inst']]    
        
        #Index where Mississippi Basin longitude/latitude coordinates are in the DataFrame
        df_slice = int_df[(int_df.lon.isin(list(np.arange(-90.5,-100,-0.5)))) & (int_df.lat.isin(list(np.arange(30.5,40,0.5))))]
        miss_region_df = pd.concat([miss_region_df, df_slice], axis=0)
        
    except:
        pass

# %%
#Sorting and shaping DataFrame
miss_region_df = miss_region_df.sort_values(by=['time'])
miss_region_df.reset_index(inplace=True)
miss_region_df
# Out:
#         index       time   lon   lat  SWE_inst  SoilMoi0_10cm_inst  \
# 0       67449 1948-01-01 -90.5  39.5  3.806316           32.123287
# 1       13141 1948-01-01 -92.5  31.5  2.229555           27.859627
# 2       13140 1948-01-01 -92.5  30.5  1.618988           33.884422
# 3       12999 1948-01-01 -93.5  39.5  8.648218           27.661360
# 4       12998 1948-01-01 -93.5  38.5  4.152470           29.399712
# ...       ...        ...   ...   ...       ...                 ...
# 160795  12998 2014-12-01 -93.5  38.5  0.093266           30.214924
# 160796  12999 2014-12-01 -93.5  39.5  0.034194           28.063148
# 160797  13140 2014-12-01 -92.5  30.5  0.000000           32.061871
# 160798  13142 2014-12-01 -92.5  32.5  0.000000           24.142153
# 160799  13448 2014-12-01 -90.5  38.5  0.000847           30.532423
#
#         SoilMoi10_40cm_inst  SoilMoi40_100cm_inst  SoilMoi100_200cm_inst
# 0                 92.026428            170.576889             278.188965
# 1                 83.313400            164.319550             260.117340
# 2                101.597855            204.641144             346.735229
# 3                 84.057205            158.720032             252.469193
# 4                 90.760048            176.681396             292.177612
# ...                     ...                   ...                    ...
# 160795            90.772018            181.880325             304.265106
# 160796            84.597443            169.497864             283.173187
# 160797            96.579048            194.730820             330.652588
# 160798            72.722046            144.230743             233.939163
# 160799            91.923943            186.014633             315.789154
#
# [160800 rows x 9 columns]

# %%
mississ_avg_df = pd.DataFrame()

for ts in list(collections.Counter(miss_region_df["time"]).keys()):
    sub_region_df = miss_region_df[miss_region_df["time"] == ts]
    mississ_avg_df = pd.concat([mississ_avg_df, sub_region_df.describe().iloc[1]], axis=1)

# %%
mississ_avg_df = mississ_avg_df.transpose()

# %%
trunc_nldas = mississ_avg_df[(mississ_avg_df['time'] > '2002-04-18 00:00:00') & (mississ_avg_df['time'] < '2014-12-31 00:00:00')]

# %%
trunc_nldas
# Out:
#         index       time   lon   lat  SWE_inst SoilMoi0_10cm_inst  \
# mean  39769.5 2002-05-01 -95.0  35.0       0.0          27.850849
# mean  39769.5 2002-06-01 -95.0  35.0       0.0          26.660673
# mean  39769.5 2002-07-01 -95.0  35.0       0.0          25.896763
# mean  39769.5 2002-08-01 -95.0  35.0       0.0           24.13991
# mean  39769.5 2002-09-01 -95.0  35.0       0.0          22.446699
# ...       ...        ...   ...   ...       ...                ...
# mean  39769.5 2014-08-01 -95.0  35.0       0.0          21.316051
# mean  39769.5 2014-09-01 -95.0  35.0       0.0          21.880833
# mean  39769.5 2014-10-01 -95.0  35.0       0.0          23.376719
# mean  39769.5 2014-11-01 -95.0  35.0  0.130912          23.874025
# mean  39769.5 2014-12-01 -95.0  35.0  0.083355          24.092285
#
#      SoilMoi10_40cm_inst SoilMoi40_100cm_inst SoilMoi100_200cm_inst
# mean           83.430878           161.056534            300.847504
# mean           79.764427            152.99733            293.075409
# mean           76.763695           141.349762            277.454376
# mean           72.083038           132.881271            269.780029
# mean           67.355751           123.209671            263.925323
# ...                  ...                  ...                   ...
# mean           63.217739           116.984123            260.198944
# mean           62.999062           107.587692            250.570816
# mean           70.432167           120.297569            250.227936
# mean            73.75341           132.581177            254.966522
# mean           73.997536           138.522095            261.502045
#
# [152 rows x 9 columns]

# %%
#Converting values to meters

trunc_nldas["SWE_inst"] = trunc_nldas["SWE_inst"]*0.001
trunc_nldas["SoilMoi0_10cm_inst"] = trunc_nldas["SoilMoi0_10cm_inst"]*0.001
trunc_nldas["SoilMoi10_40cm_inst"] = trunc_nldas["SoilMoi10_40cm_inst"]*0.001
trunc_nldas["SoilMoi40_100cm_inst"] = trunc_nldas["SoilMoi40_100cm_inst"]*0.001
trunc_nldas["SoilMoi100_200cm_inst"] = trunc_nldas["SoilMoi100_200cm_inst"]*0.001
# Out:
# /tmp/ipykernel_76783/839424738.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trunc_nldas["SoilMoi0_10cm_inst"] = trunc_nldas["SoilMoi0_10cm_inst"]*0.001
# /tmp/ipykernel_76783/839424738.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trunc_nldas["SoilMoi10_40cm_inst"] = trunc_nldas["SoilMoi10_40cm_inst"]*0.001
# /tmp/ipykernel_76783/839424738.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trunc_nldas["SoilMoi40_100cm_inst"] = trunc_nldas["SoilMoi40_100cm_inst"]*0.001
# /tmp/ipykernel_76783/839424738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trunc_nldas["SoilMoi100_200cm_inst"] = trunc_nldas["SoilMoi100_200cm_inst"]*0.001

# %%
trunc_nldas
# Out:
#         index       time   lon   lat  SWE_inst SoilMoi0_10cm_inst  \
# mean  39769.5 2002-05-01 -95.0  35.0       0.0           0.027851
# mean  39769.5 2002-06-01 -95.0  35.0       0.0           0.026661
# mean  39769.5 2002-07-01 -95.0  35.0       0.0           0.025897
# mean  39769.5 2002-08-01 -95.0  35.0       0.0            0.02414
# mean  39769.5 2002-09-01 -95.0  35.0       0.0           0.022447
# ...       ...        ...   ...   ...       ...                ...
# mean  39769.5 2014-08-01 -95.0  35.0       0.0           0.021316
# mean  39769.5 2014-09-01 -95.0  35.0       0.0           0.021881
# mean  39769.5 2014-10-01 -95.0  35.0       0.0           0.023377
# mean  39769.5 2014-11-01 -95.0  35.0  0.000131           0.023874
# mean  39769.5 2014-12-01 -95.0  35.0  0.000083           0.024092
#
#      SoilMoi10_40cm_inst SoilMoi40_100cm_inst SoilMoi100_200cm_inst
# mean            0.083431             0.161057              0.300848
# mean            0.079764             0.152997              0.293075
# mean            0.076764              0.14135              0.277454
# mean            0.072083             0.132881               0.26978
# mean            0.067356              0.12321              0.263925
# ...                  ...                  ...                   ...
# mean            0.063218             0.116984              0.260199
# mean            0.062999             0.107588              0.250571
# mean            0.070432             0.120298              0.250228
# mean            0.073753             0.132581              0.254967
# mean            0.073998             0.138522              0.261502
#
# [152 rows x 9 columns]

# %%
#Creating column with only year and month

year_mon_nldas = []

for d in trunc_nldas["time"]:
    year_mon_nldas.append(str(d)[0:7])

# %%
trunc_nldas["year_mon"] = year_mon_nldas
# Out:
# /tmp/ipykernel_76783/4232225344.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trunc_nldas["year_mon"] = year_mon_nldas

# %%
trunc_nldas
# Out:
#         index       time   lon   lat  SWE_inst SoilMoi0_10cm_inst  \
# mean  39769.5 2002-05-01 -95.0  35.0       0.0           0.027851
# mean  39769.5 2002-06-01 -95.0  35.0       0.0           0.026661
# mean  39769.5 2002-07-01 -95.0  35.0       0.0           0.025897
# mean  39769.5 2002-08-01 -95.0  35.0       0.0            0.02414
# mean  39769.5 2002-09-01 -95.0  35.0       0.0           0.022447
# ...       ...        ...   ...   ...       ...                ...
# mean  39769.5 2014-08-01 -95.0  35.0       0.0           0.021316
# mean  39769.5 2014-09-01 -95.0  35.0       0.0           0.021881
# mean  39769.5 2014-10-01 -95.0  35.0       0.0           0.023377
# mean  39769.5 2014-11-01 -95.0  35.0  0.000131           0.023874
# mean  39769.5 2014-12-01 -95.0  35.0  0.000083           0.024092
#
#      SoilMoi10_40cm_inst SoilMoi40_100cm_inst SoilMoi100_200cm_inst year_mon
# mean            0.083431             0.161057              0.300848  2002-05
# mean            0.079764             0.152997              0.293075  2002-06
# mean            0.076764              0.14135              0.277454  2002-07
# mean            0.072083             0.132881               0.26978  2002-08
# mean            0.067356              0.12321              0.263925  2002-09
# ...                  ...                  ...                   ...      ...
# mean            0.063218             0.116984              0.260199  2014-08
# mean            0.062999             0.107588              0.250571  2014-09
# mean            0.070432             0.120298              0.250228  2014-10
# mean            0.073753             0.132581              0.254967  2014-11
# mean            0.073998             0.138522              0.261502  2014-12
#
# [152 rows x 10 columns]

# %%
overlap_nldas = trunc_nldas[(trunc_nldas.year_mon.isin(overlap_set))]

# %%
overlap_nldas
# Out:
#         index       time   lon   lat  SWE_inst SoilMoi0_10cm_inst  \
# mean  39769.5 2002-05-01 -95.0  35.0       0.0           0.027851
# mean  39769.5 2002-08-01 -95.0  35.0       0.0            0.02414
# mean  39769.5 2002-09-01 -95.0  35.0       0.0           0.022447
# mean  39769.5 2002-10-01 -95.0  35.0  0.000023           0.027162
# mean  39769.5 2002-11-01 -95.0  35.0  0.000007           0.026656
# ...       ...        ...   ...   ...       ...                ...
# mean  39769.5 2014-06-01 -95.0  35.0       0.0           0.027338
# mean  39769.5 2014-08-01 -95.0  35.0       0.0           0.021316
# mean  39769.5 2014-09-01 -95.0  35.0       0.0           0.021881
# mean  39769.5 2014-10-01 -95.0  35.0       0.0           0.023377
# mean  39769.5 2014-11-01 -95.0  35.0  0.000131           0.023874
#
#      SoilMoi10_40cm_inst SoilMoi40_100cm_inst SoilMoi100_200cm_inst year_mon
# mean            0.083431             0.161057              0.300848  2002-05
# mean            0.072083             0.132881               0.26978  2002-08
# mean            0.067356              0.12321              0.263925  2002-09
# mean            0.080392             0.144818               0.27413  2002-10
# mean            0.082098             0.163777               0.28732  2002-11
# ...                  ...                  ...                   ...      ...
# mean            0.081056             0.145997              0.283316  2014-06
# mean            0.063218             0.116984              0.260199  2014-08
# mean            0.062999             0.107588              0.250571  2014-09
# mean            0.070432             0.120298              0.250228  2014-10
# mean            0.073753             0.132581              0.254967  2014-11
#
# [138 rows x 10 columns]

# %% [markdown]
# ## GRACE Data

# %%
grace_path = '/home/maiampow/remoteData/GRACE/data/TELLUS_GRAC_L3_CSR_RL06_LND_v04/'

# %%
def read_data(path, filename, data):
    try:
        if filename.endswith('nc'):
            df = xr.open_dataset(path+str(filename))
            date = pd.to_datetime(df['time'].values[0])
            data['date'].append(date)
            region = df['lwe_thickness'].sel(lat=slice(30.5, 39.5), lon=slice(270.5, 279.5))
            data['lwe_thickness'].append(region.mean().values.item())
        else:
            pass
    except Exception as e:
        print(e)
        print(path)
        print(filename)

# %%
data = {'date':[], 'lwe_thickness':[]}

for filename in os.listdir(grace_path):
    read_data(grace_path, filename, data)

# %%
df = pd.DataFrame(data)
df = df.sort_values('date')

# %%
df
# Out:
#                    date  lwe_thickness
# 162 2002-04-18 00:00:00       0.051939
# 161 2002-05-10 12:00:00       0.044236
# 160 2002-08-16 12:00:00      -0.108040
# 159 2002-09-16 00:00:00      -0.120404
# 158 2002-10-16 12:00:00      -0.060526
# ..                  ...            ...
# 4   2017-01-21 00:00:00       0.054049
# 3   2017-03-31 12:00:00       0.073723
# 2   2017-04-24 12:00:00       0.050132
# 1   2017-05-13 00:00:00       0.058987
# 0   2017-06-10 12:00:00       0.066782
#
# [163 rows x 2 columns]

# %%
trunc_grace = df[(df['date'] > '2002-01-01 00:00:00') & (df['date'] < '2014-12-31 00:00:00')]

# %%
trunc_grace.reset_index(inplace=True)

# %%
#Creating column with only year and month

year_mon_grace = []

for d in trunc_grace["date"]:
    year_mon_grace.append(str(d)[0:7])

# %%
trunc_grace["year_mon"] = year_mon_grace
# Out:
# /tmp/ipykernel_76783/1312667246.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trunc_grace["year_mon"] = year_mon_grace

# %%
trunc_grace
# Out:
#      index                date  lwe_thickness year_mon
# 0      162 2002-04-18 00:00:00       0.051939  2002-04
# 1      161 2002-05-10 12:00:00       0.044236  2002-05
# 2      160 2002-08-16 12:00:00      -0.108040  2002-08
# 3      159 2002-09-16 00:00:00      -0.120404  2002-09
# 4      158 2002-10-16 12:00:00      -0.060526  2002-10
# ..     ...                 ...            ...      ...
# 135     27 2014-06-13 00:00:00       0.034361  2014-06
# 136     26 2014-08-16 12:00:00      -0.036681  2014-08
# 137     25 2014-09-16 00:00:00      -0.072096  2014-09
# 138     24 2014-10-16 12:00:00      -0.073428  2014-10
# 139     23 2014-11-16 00:00:00      -0.045895  2014-11
#
# [140 rows x 4 columns]

# %%
plt.style.use('ggplot')
plt.plot(df["lwe_thickness"])
plt.show()

# %% [markdown]
# ## Finding overlap in NLDAS and GRACE months

# %%
gr_set = set(year_mon_grace)
nl_set = set(year_mon_nldas)

# %%
overlap_set = list(gr_set.intersection(nl_set))

# %%
overlap_grace = trunc_grace[(trunc_grace.year_mon.isin(overlap_set))]

# %%
overlap_grace
# Out:
#      index                date  lwe_thickness year_mon
# 1      161 2002-05-10 12:00:00       0.044236  2002-05
# 2      160 2002-08-16 12:00:00      -0.108040  2002-08
# 3      159 2002-09-16 00:00:00      -0.120404  2002-09
# 4      158 2002-10-16 12:00:00      -0.060526  2002-10
# 5      157 2002-11-16 00:00:00      -0.015423  2002-11
# ..     ...                 ...            ...      ...
# 135     27 2014-06-13 00:00:00       0.034361  2014-06
# 136     26 2014-08-16 12:00:00      -0.036681  2014-08
# 137     25 2014-09-16 00:00:00      -0.072096  2014-09
# 138     24 2014-10-16 12:00:00      -0.073428  2014-10
# 139     23 2014-11-16 00:00:00      -0.045895  2014-11
#
# [139 rows x 4 columns]

# %%
overlap_grace.iloc[108]
# Out:
# index                             53
# date             2011-10-16 12:00:00
# lwe_thickness              -0.111376
# year_mon                     2011-10
# Name: 109, dtype: object

# %%
#Deleting redundant row
overlap_grace = overlap_grace.drop(labels=108, axis=0)

# %%
overlap_grace.reset_index(inplace=True)

# %% [markdown]
# # ΔGW = ΔTWS - (ΔSM + ΔSWE)

# %%
gw_estimate = []

for i in range(0, len(overlap_grace)):
    gw_estimate.append(  overlap_grace["lwe_thickness"][i] - ( overlap_nldas["SoilMoi0_10cm_inst"][i] + overlap_nldas["SWE_inst"][i] ) )

# %%
plt.style.use('ggplot')
plt.figure(figsize=(12,8))
plt.plot(overlap_grace["year_mon"],gw_estimate, color="green")
plt.title("Groundwater Estimate \n ΔGW = ΔTWS - (ΔSM + ΔSWE)",fontsize=20)
plt.xlabel("Time in Months")
plt.ylabel("Water Storage in Meters")
plt.xticks(overlap_grace["year_mon"], rotation=90,fontsize=6)
plt.show()
