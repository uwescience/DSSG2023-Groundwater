# %%
import netCDF4 as nc
import pandas as pd
import os
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import collections
import matplotlib.font_manager
import xarray as xr
import statistics

# %%
# Defining path to GLDAS_NOAH10_M data
p = "/home/maiampow/remoteData/GLDAS_NEW/GLDAS_NOAH10_M/"

# %%
# Creating dataframe for only Mississippi Basin (Lat, Lon = [47.5,95.5])

mississ_df = pd.DataFrame()

#Iterating through files in path
for filename in os.listdir(p):
    try:
        #Reading in data as xarray then converting to DataFrame
        xd = xr.open_dataset(p+str(filename))
        xd_df = xd.to_dataframe()
        xd_df.reset_index(inplace=True)
        
        #Extracting only needed columns 
        int_df = xd_df[["time", "lon", "lat", "SWE_inst", 'SoilMoi0_10cm_inst',
           'SoilMoi10_40cm_inst', 'SoilMoi40_100cm_inst', 'SoilMoi100_200cm_inst']]    
        
        #Index where Mississippi Basin longitude/latitude coordinates are in the DataFrame
        df_slice = int_df.iloc[95357] 
        
        mississ_df = pd.concat([mississ_df, df_slice], axis=1)
    except:
        pass

# %%
#Sorting and shaping DataFrame
mississ_df = mississ_df.transpose()
mississ_df = mississ_df.sort_values(by=['time'])
mississ_df
# Out:
#             time   lon   lat  SWE_inst SoilMoi0_10cm_inst SoilMoi10_40cm_inst  \
# 95357 1948-01-01  95.5  47.5  0.442591          11.573445           51.718342
# 95357 1948-02-01  95.5  47.5  0.398707          11.110646            51.71833
# 95357 1948-03-01  95.5  47.5  0.524073          10.682569           51.718102
# 95357 1948-04-01  95.5  47.5  0.032042          12.813025           51.664322
# 95357 1948-05-01  95.5  47.5  0.032056           14.85473           51.383934
# ...          ...   ...   ...       ...                ...                 ...
# 95357 2014-08-01  95.5  47.5       0.0          15.328012           47.783836
# 95357 2014-09-01  95.5  47.5  0.011917          16.006437           48.024326
# 95357 2014-10-01  95.5  47.5  0.043145          15.167588           46.834347
# 95357 2014-11-01  95.5  47.5  0.223667          12.932709            46.41626
# 95357 2014-12-01  95.5  47.5  0.610484          12.015084           46.407791
#
#       SoilMoi40_100cm_inst SoilMoi100_200cm_inst
# 95357            96.965424            192.793671
# 95357            96.965424            192.793671
# 95357            96.965111            192.793671
# 95357            96.944405            192.793671
# 95357            96.761818            192.828583
# ...                    ...                   ...
# 95357            85.130653            180.410294
# 95357            83.788216            180.108322
# 95357            83.383392            179.809143
# 95357            83.342369            179.665054
# 95357            83.334808            179.622284
#
# [804 rows x 8 columns]

# %%
# Creating dataframe for only Mississippi Basin 

miss_region_df = pd.DataFrame()

#Iterating through files in path
for filename in os.listdir(p):
    try:
        #Reading in data as xarray then converting to DataFrame
        xd = xr.open_dataset(p+str(filename))
        xd_df = xd.to_dataframe()
        xd_df.reset_index(inplace=True)
        
        #Extracting only needed columns 
        int_df = xd_df[["time", "lon", "lat", "SWE_inst", 'SoilMoi0_10cm_inst',
           'SoilMoi10_40cm_inst', 'SoilMoi40_100cm_inst', 'SoilMoi100_200cm_inst']]    
        
        #Index where Mississippi Basin longitude/latitude coordinates are in the DataFrame
        df_slice = int_df[(int_df.lon.isin(list(np.arange(-90.5,-100,-0.5)))) & (int_df.lat.isin(list(np.arange(30.5,40,0.5))))]
        miss_region_df = pd.concat([miss_region_df, df_slice], axis=0)
        
    except:
        pass

# %%
#Sorting and shaping DataFrame
miss_region_df = miss_region_df.sort_values(by=['time'])
miss_region_df.reset_index(inplace=True)
miss_region_df
# Out:
#         index       time   lon   lat   SWE_inst  SoilMoi0_10cm_inst  \
# 0       67449 1948-01-01 -90.5  39.5   3.806316           32.123287
# 1       67447 1948-01-01 -90.5  37.5   2.485263           32.359039
# 2       67446 1948-01-01 -90.5  36.5  19.690971           36.345371
# 3       67445 1948-01-01 -90.5  35.5   4.440931           34.896969
# 4       67444 1948-01-01 -90.5  34.5   4.525668           35.488300
# ...       ...        ...   ...   ...        ...                 ...
# 160795  67441 2014-12-01 -90.5  31.5   0.000000           30.983685
# 160796  67442 2014-12-01 -90.5  32.5   0.000000           30.781475
# 160797  67443 2014-12-01 -90.5  33.5   0.000000           34.292168
# 160798  67293 2014-12-01 -91.5  33.5   0.000000           29.843758
# 160799  13448 2014-12-01 -90.5  38.5   0.000847           30.532423
#
#         SoilMoi10_40cm_inst  SoilMoi40_100cm_inst  SoilMoi100_200cm_inst
# 0                 92.026428            170.576889             278.188965
# 1                100.338165            197.472061             332.425110
# 2                101.881203            207.340408             382.714020
# 3                104.153519            215.375290             394.772217
# 4                106.008339            219.272903             406.972290
# ...                     ...                   ...                    ...
# 160795            93.322258            187.973190             317.353302
# 160796            91.917381            181.681717             299.387726
# 160797           102.738617            200.841995             359.385010
# 160798            89.629120            179.397720             300.578583
# 160799            91.923943            186.014633             315.789154
#
# [160800 rows x 9 columns]

# %%
ts = list(collections.Counter(miss_region_df["time"]).keys())[0]

# %%
mississ_avg_df = pd.DataFrame()

for ts in list(collections.Counter(miss_region_df["time"]).keys()):
    sub_region_df = miss_region_df[miss_region_df["time"] == ts]
    mississ_avg_df = pd.concat([mississ_avg_df, sub_region_df.describe().iloc[1]], axis=1)

# %%
mississ_avg_df = mississ_avg_df.transpose()

# %%
mississ_avg_df = mississ_avg_df[]
# Out:
#         index       time   lon   lat  SWE_inst SoilMoi0_10cm_inst  \
# mean  39769.5 1948-01-01 -95.0  35.0  1.829879          26.013916
# mean  39769.5 1948-02-01 -95.0  35.0  1.082676          27.866779
# mean  39769.5 1948-03-01 -95.0  35.0  0.436915          28.846594
# mean  39769.5 1948-04-01 -95.0  35.0  0.000533          26.062387
# mean  39769.5 1948-05-01 -95.0  35.0       0.0          25.431303
# ...       ...        ...   ...   ...       ...                ...
# mean  39769.5 2014-08-01 -95.0  35.0       0.0          21.316055
# mean  39769.5 2014-09-01 -95.0  35.0       0.0          21.880835
# mean  39769.5 2014-10-01 -95.0  35.0       0.0          23.376719
# mean  39769.5 2014-11-01 -95.0  35.0  0.130912          23.874023
# mean  39769.5 2014-12-01 -95.0  35.0  0.083355          24.092285
#
#      SoilMoi10_40cm_inst SoilMoi40_100cm_inst SoilMoi100_200cm_inst
# mean           77.677704           141.231918            275.914001
# mean           82.964218           148.103241            284.956451
# mean           87.490021           163.193222            294.121094
# mean           79.469826           155.810593            288.711914
# mean           74.906258           142.035706             277.70224
# ...                  ...                  ...                   ...
# mean           63.217735           116.984123            260.198944
# mean           62.999062           107.587685            250.570801
# mean           70.432167           120.297577            250.227936
# mean           73.753403           132.581177            254.966522
# mean           73.997543           138.522095            261.502075
#
# [804 rows x 9 columns]

# %%
#Plotting Snow Water Equivalent over 804 Months 
plt.style.use('ggplot')
plt.figure(figsize=(10,6))
plt.plot(list(mississ_avg_df["SWE_inst"]), color="darkmagenta")
plt.xlabel("Months")
plt.ylabel("Snow Water Equivalent ($kg\ m^{-2}$)")
plt.title("Snow Water Equivalent (by month in $kg\ m^{-2}$) \n Averaged Over Mississippi Basin")
plt.show()

# %%
#Plotting Soil Moisture Content at different depths over 804 months
plt.style.use('ggplot')
plt.figure(figsize=(12,8))
plt.plot(list(mississ_avg_df["SoilMoi0_10cm_inst"]), color="powderblue")
plt.plot(list(mississ_avg_df["SoilMoi10_40cm_inst"]), color="mediumturquoise")
plt.plot(list(mississ_avg_df["SoilMoi40_100cm_inst"]), color="darkcyan")
plt.plot(list(mississ_avg_df["SoilMoi100_200cm_inst"]), color="darkslategrey")
plt.xlabel("Months")
plt.ylabel("Soil Moisture Content ($kg/m^2$)")
plt.legend(["0-10cm", "10-40cm", "40-100cm", "100-200cm"],facecolor='w')
plt.title("Soil Moisture Content by Month in $kg/m^2$ \n Averaged Over Mississippi Basin")
plt.show()

# %%
xv_df = xd.to_dataframe()
xv_df.reset_index(inplace=True)

# %%
xxx_df = xv_df[(xv_df.lon.isin(list(np.arange(-90.5,-100,-0.5)))) & (xv_df.lat.isin(list(np.arange(30.5,40,0.5))))]

# %%
xxx_df = xxx_df[xxx_df.SWE_inst.notnull()]

# %%
xxx_df
# Out:
#             time  bnds   lon   lat  time_bnds  Swnet_tavg  Lwnet_tavg  \
# 12090 1948-01-01     0 -99.5  30.5 1948-01-01  107.764076  -57.916859
# 12091 1948-01-01     0 -99.5  31.5 1948-01-01  103.823189  -58.279804
# 12092 1948-01-01     0 -99.5  32.5 1948-01-01  100.568062  -57.242466
# 12093 1948-01-01     0 -99.5  33.5 1948-01-01   96.487259  -56.461254
# 12094 1948-01-01     0 -99.5  34.5 1948-01-01   85.227463  -52.785973
# ...          ...   ...   ...   ...        ...         ...         ...
# 67445 1948-01-01     1 -90.5  35.5 1948-02-01   76.919640  -53.317467
# 67446 1948-01-01     1 -90.5  36.5 1948-02-01   59.100807  -46.314644
# 67447 1948-01-01     1 -90.5  37.5 1948-02-01   80.103592  -47.966499
# 67448 1948-01-01     1 -90.5  38.5 1948-02-01   63.893105  -45.943836
# 67449 1948-01-01     1 -90.5  39.5 1948-02-01   66.608223  -42.920650
#
#         Qle_tavg    Qh_tavg    Qg_tavg  ...  ESoil_tavg  RootMoist_inst  \
# 12090  13.040191  42.738060  -5.829228  ...    8.176412      180.437164
# 12091  10.153538  42.196125  -6.706768  ...    7.215282      150.385986
# 12092   6.574707  42.994312  -6.150558  ...    4.666411      120.360298
# 12093   6.887650  40.454311  -7.267857  ...    3.801935      161.180222
# 12094   9.346925  29.287374  -7.109953  ...    0.994395      147.062775
# ...          ...        ...        ...  ...         ...             ...
# 67445  24.566118   7.662254 -10.493340  ...   14.855564      354.425842
# 67446  18.489143  -1.123391  -9.533340  ...    9.523629      423.681610
# 67447  19.796764  26.326206 -14.594792  ...   12.293670      595.384094
# 67448  22.813942  11.408262 -18.588743  ...    9.385283      386.794403
# 67449  21.480957  15.091972 -14.299510  ...   11.506774      294.726593
#
#        CanopInt_inst  Wind_f_inst  Rainf_f_tavg  Tair_f_inst  Qair_f_inst  \
# 12090       0.019907     3.908797      0.000004   278.603790     0.003533
# 12091       0.020053     4.121752      0.000006   277.677032     0.003350
# 12092       0.014628     4.133493      0.000003   276.648682     0.003063
# 12093       0.013389     4.137947      0.000004   274.997253     0.002908
# 12094       0.054397     4.050902      0.000006   274.474243     0.002992
# ...              ...          ...           ...          ...          ...
# 67445       0.227943     3.939161      0.000030   274.044708     0.003614
# 67446       0.236547     3.909201      0.000031   272.778320     0.003344
# 67447       0.127522     3.955760      0.000035   270.237213     0.002836
# 67448       0.277085     4.156570      0.000021   269.455475     0.002667
# 67449       0.194162     4.374383      0.000014   268.278931     0.002436
#
#         Psurf_f_inst  SWdown_f_tavg  LWdown_f_tavg
# 12090   96998.515625     122.243790     284.631195
# 12091   95819.789062     118.002419     279.500519
# 12092   95649.593750     114.584274     275.603577
# 12093   95592.164062     111.702660     268.975250
# 12094   96114.703125     106.492256     268.965149
# ...              ...            ...            ...
# 67445  100995.968750     100.007660     261.346558
# 67446  100733.437500      95.727982     259.236023
# 67447  100503.804688      93.720886     253.467484
# 67448  100301.695312      90.896454     249.852570
# 67449  100000.109375      88.923386     249.538971
#
# [200 rows x 41 columns]

# %%
worldmap = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))

# Creating axes and plotting world map
fig, ax = plt.subplots(figsize=(12, 6))
worldmap.plot(color="lightgrey", ax=ax)

x = xxx_df['lon']
y = xxx_df['lat']
z = xxx_df['SWE_inst']
plt.scatter(x, y, c=z, alpha=0.25,
            cmap='Blues')
plt.colorbar(label='SWE')

# Creating axis limits and title
plt.xlim([-180, 180])
plt.ylim([-90, 90])

plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()
# Out:
# /tmp/ipykernel_9024/2460267070.py:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   worldmap = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))

# %%
#Plotting Snow Water Equivalent over 804 Months 
plt.style.use('ggplot')
plt.figure(figsize=(10,6))
plt.plot(list(mississ_df["SWE_inst"]), color="darkmagenta")
plt.xlabel("Months")
plt.ylabel("Snow Water Equivalent ($kg\ m^{-2}$)")
plt.title("Snow Water Equivalent (by month in $kg\ m^{-2}$)")
plt.show()

# %%
#Plotting Soil Moisture Content at different depths over 804 months
plt.style.use('ggplot')
plt.figure(figsize=(12,8))
plt.plot(list(mississ_df["SoilMoi0_10cm_inst"]), color="powderblue")
plt.plot(list(mississ_df["SoilMoi10_40cm_inst"]), color="mediumturquoise")
plt.plot(list(mississ_df["SoilMoi40_100cm_inst"]), color="darkcyan")
plt.plot(list(mississ_df["SoilMoi100_200cm_inst"]), color="darkslategrey")
plt.xlabel("Months")
plt.ylabel("Soil Moisture Content ($kg/m^2$)")
plt.legend(["0-10cm", "10-40cm", "40-100cm", "100-200cm"],facecolor='w')
plt.title("Soil Moisture Content by Month in $kg/m^2$")
plt.show()

# %%
#Reading in data for one (random) month
xd = xr.open_dataset("/home/maiampow/remoteData/GLDAS_NEW/GLDAS_NOAH10_M/GLDAS_NOAH10_M.A198112.020.nc4")

# %%
xr_df = xd.to_dataframe()
xr_df.reset_index(inplace=True)

# %%
latlon_df = xr_df[["time", "lon", "lat", "SWE_inst", 'SoilMoi0_10cm_inst',
           'SoilMoi10_40cm_inst', 'SoilMoi40_100cm_inst', 'SoilMoi100_200cm_inst']]

# %%
latlon_df
# Out:
#              time    lon   lat  SWE_inst  SoilMoi0_10cm_inst  \
# 0      1981-12-01 -179.5 -59.5       NaN                 NaN
# 1      1981-12-01 -179.5 -58.5       NaN                 NaN
# 2      1981-12-01 -179.5 -57.5       NaN                 NaN
# 3      1981-12-01 -179.5 -56.5       NaN                 NaN
# 4      1981-12-01 -179.5 -55.5       NaN                 NaN
# ...           ...    ...   ...       ...                 ...
# 107995 1981-12-01  179.5  85.5       NaN                 NaN
# 107996 1981-12-01  179.5  86.5       NaN                 NaN
# 107997 1981-12-01  179.5  87.5       NaN                 NaN
# 107998 1981-12-01  179.5  88.5       NaN                 NaN
# 107999 1981-12-01  179.5  89.5       NaN                 NaN
#
#         SoilMoi10_40cm_inst  SoilMoi40_100cm_inst  SoilMoi100_200cm_inst
# 0                       NaN                   NaN                    NaN
# 1                       NaN                   NaN                    NaN
# 2                       NaN                   NaN                    NaN
# 3                       NaN                   NaN                    NaN
# 4                       NaN                   NaN                    NaN
# ...                     ...                   ...                    ...
# 107995                  NaN                   NaN                    NaN
# 107996                  NaN                   NaN                    NaN
# 107997                  NaN                   NaN                    NaN
# 107998                  NaN                   NaN                    NaN
# 107999                  NaN                   NaN                    NaN
#
# [108000 rows x 8 columns]

# %%
ll_half = latlon_df[54000:] #Eliminating duplicates

# %%
ll_half = ll_half[ll_half.SWE_inst.notnull()] #Removing rows with NaN values

# %%
ll_half = ll_half.sort_values(by=['time'])

# %%
x = ll_half['lon']
y = ll_half['lat']
z = ll_half['SWE_inst']
plt.figure(figsize=(10,6))
plt.scatter(x, y, c=z, alpha=0.25,
            cmap='Blues')
plt.colorbar(label='SWE')

# Creating axis limits and title
plt.xlim([-180, 180])
plt.ylim([-90, 90])

#first_year = df["Datetime"].min().strftime("%Y")
#last_year = df["Datetime"].max().strftime("%Y")
#plt.title("NASA: Fireballs Reported by Government Sensors\n" +     
#          str(first_year) + " - " + str(last_year))
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()

# %%
#Finding Mississippi Basin coordinates in DataFrame

for i in range(0,len(latlon_df)):
    if list(latlon_df.iloc[i]) == [95.5,47.5]:
        print(i)
# Out:
# 41357
# 95357

# %%
#Creating array of lon/lat coordinates provided by GLDAS

lat_lon_coords = np.empty((150,360),dtype=object)

xd_lat = np.array(xd["lat"]).flatten()
xd_lon = np.array(xd["lon"]).flatten()

for i in range(0,len(xd_lat)):
    for j in range(0,len(xd_lon)):
        lat_lon_coords[i,j] = (xd_lat[i], xd_lon[i])

# %%
lat_lon_coords
# Out:
# array([[(-59.5, -179.5), (-59.5, -179.5), (-59.5, -179.5), ...,
#         (-59.5, -179.5), (-59.5, -179.5), (-59.5, -179.5)],
#        [(-58.5, -178.5), (-58.5, -178.5), (-58.5, -178.5), ...,
#         (-58.5, -178.5), (-58.5, -178.5), (-58.5, -178.5)],
#        [(-57.5, -177.5), (-57.5, -177.5), (-57.5, -177.5), ...,
#         (-57.5, -177.5), (-57.5, -177.5), (-57.5, -177.5)],
#        ...,
#        [(87.5, -32.5), (87.5, -32.5), (87.5, -32.5), ..., (87.5, -32.5),
#         (87.5, -32.5), (87.5, -32.5)],
#        [(88.5, -31.5), (88.5, -31.5), (88.5, -31.5), ..., (88.5, -31.5),
#         (88.5, -31.5), (88.5, -31.5)],
#        [(89.5, -30.5), (89.5, -30.5), (89.5, -30.5), ..., (89.5, -30.5),
#         (89.5, -30.5), (89.5, -30.5)]], dtype=object)

# %%
#Initial data exploration

p1 = "/home/maiampow/remoteData/GLDAS/NOAH_monthly"

noah_d1 = pd.DataFrame()

for filename in os.listdir(p1):
    try:
        data = nc.Dataset(p1+str(filename))
        df = pd.DataFrame([data.variables])
        noah_d1 = pd.concat([noah_d1, df], axis=0)
    except:
        pass

# %%
noah_d1.columns
# Out:
# Index(['time', 'time_bnds', 'lon', 'lat', 'Swnet_tavg', 'Lwnet_tavg',
#        'Qle_tavg', 'Qh_tavg', 'Qg_tavg', 'Snowf_tavg', 'Rainf_tavg',
#        'Evap_tavg', 'Qs_acc', 'Qsb_acc', 'Qsm_acc', 'AvgSurfT_inst',
#        'Albedo_inst', 'SWE_inst', 'SnowDepth_inst', 'SoilMoi0_10cm_inst',
#        'SoilMoi10_40cm_inst', 'SoilMoi40_100cm_inst', 'SoilMoi100_200cm_inst',
#        'SoilTMP0_10cm_inst', 'SoilTMP10_40cm_inst', 'SoilTMP40_100cm_inst',
#        'SoilTMP100_200cm_inst', 'PotEvap_tavg', 'ECanop_tavg', 'Tveg_tavg',
#        'ESoil_tavg', 'RootMoist_inst', 'CanopInt_inst', 'Wind_f_inst',
#        'Rainf_f_tavg', 'Tair_f_inst', 'Qair_f_inst', 'Psurf_f_inst',
#        'SWdown_f_tavg', 'LWdown_f_tavg'],
#       dtype='object')
