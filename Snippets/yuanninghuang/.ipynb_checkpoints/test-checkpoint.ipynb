# %%
import xarray as xr
import numpy as np
import pandas as pd
import os
import re
import datetime
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-7d59321644a6> in <module>
# ----> 1 import xarray as xr
#       2 import numpy as np
#       3 import pandas as pd
#       4 import os
#       5 import re
#
# ModuleNotFoundError: No module named 'xarray'

# %%
pip install xarray
# Out:
# Collecting xarray
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/10/6f/9aa15b1f9001593d51a0e417a8ad2127ef384d08129a0720b3599133c1ed/xarray-0.16.2-py3-none-any.whl (736kB)
#     100% |████████████████████████████████| 737kB 2.3MB/s eta 0:00:01
# Collecting pandas>=0.25 (from xarray)
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/c3/e2/00cacecafbab071c787019f00ad84ca3185952f6bb9bca9550ed83870d4d/pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5MB)
#     100% |████████████████████████████████| 9.5MB 192kB/s  eta 0:00:01   7% |██▍                             | 706kB 83.6MB/s eta 0:00:01
# Collecting numpy>=1.15 (from xarray)
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/45/b2/6c7545bb7a38754d63048c7696804a0d947328125d81bf12beaa692c3ae3/numpy-1.19.5-cp36-cp36m-manylinux1_x86_64.whl (13.4MB)
#     100% |████████████████████████████████| 13.4MB 137kB/s  eta 0:00:01
# Requirement already satisfied: setuptools>=38.4 in /usr/local/lib/python3.6/site-packages (from xarray)
# Requirement already satisfied: pytz>=2017.2 in /usr/lib/python3.6/site-packages (from pandas>=0.25->xarray)
# Collecting python-dateutil>=2.7.3 (from pandas>=0.25->xarray)
#   Downloading https://files.pythonhosted.org/packages/36/7a/87837f39d0296e723bb9b62bbb257d0355c7f6128853c78955f57342a56d/python_dateutil-2.8.2-py2.py3-none-any.whl (247kB)
#     100% |████████████████████████████████| 256kB 6.8MB/s  eta 0:00:01
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.6/site-packages (from python-dateutil>=2.7.3->pandas>=0.25->xarray)
# Installing collected packages: numpy, python-dateutil, pandas, xarray
# Exception:
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/site-packages/pip/basecommand.py", line 215, in main
#     status = self.run(options, args)
#   File "/usr/lib/python3.6/site-packages/pip/commands/install.py", line 365, in run
#     strip_file_prefix=options.strip_file_prefix,
#   File "/usr/lib/python3.6/site-packages/pip/req/req_set.py", line 789, in install
#     **kwargs
#   File "/usr/lib/python3.6/site-packages/pip/req/req_install.py", line 854, in install
#     strip_file_prefix=strip_file_prefix
#   File "/usr/lib/python3.6/site-packages/pip/req/req_install.py", line 1069, in move_wheel_files
#     strip_file_prefix=strip_file_prefix,
#   File "/usr/lib/python3.6/site-packages/pip/wheel.py", line 345, in move_wheel_files
#     clobber(source, lib_dir, True)
#   File "/usr/lib/python3.6/site-packages/pip/wheel.py", line 316, in clobber
#     ensure_dir(destdir)
#   File "/usr/lib/python3.6/site-packages/pip/utils/__init__.py", line 83, in ensure_dir
#     os.makedirs(path)
#   File "/usr/lib64/python3.6/os.py", line 220, in makedirs
#     mkdir(name, mode)
# PermissionError: [Errno 13] Permission denied: '/usr/local/lib64/python3.6/site-packages/numpy'
# Note: you may need to restart the kernel to use updated packages.

# %%
def read_data(path, filename, data):
    try:
        if filename.endswith('nc'):
            df = xr.open_dataset(path+str(filename))
            date = pd.to_datetime(df['time'].values[0])
            data['date'].append(date)
            region = df['lwe_thickness'].sel(lat=slice(30.5, 39.5), lon=slice(270.5, 279.5))
            data['lwe_thickness'].append(region.mean().values.item())
        else:
            pass
    except Exception as e:
        print(e)
        print(path)
        print(filename)

# %%
grace_path = '/home/yhuang21/remoteData/GRACE_NEW/data/TELLUS_GRAC_L3_CSR_RL06_LND_v04/'
gracefo_path = '/home/yhuang21/remoteData/GRACEFO/'

# %%
data = {'date':[], 'lwe_thickness':[]}

for filename in os.listdir(grace_path):
    read_data(grace_path, filename, data)

for filename in os.listdir(gracefo_path):
    read_data(gracefo_path, filename, data)

# %%
df = pd.DataFrame(data)
df = df.sort_values('date')
df.dtypes
# Out:
# date             datetime64[ns]
# lwe_thickness           float64
# dtype: object

# %%
df
# Out:
#                    date  lwe_thickness
# 162 2002-04-18 00:00:00       0.051939
# 161 2002-05-10 12:00:00       0.044236
# 160 2002-08-16 12:00:00      -0.108040
# 159 2002-09-16 00:00:00      -0.120404
# 158 2002-10-16 12:00:00      -0.060526
# ..                  ...            ...
# 214 2022-11-16 00:00:00      -0.063765
# 215 2022-12-16 12:00:00      -0.006596
# 216 2023-01-16 12:00:00       0.037602
# 217 2023-02-15 00:00:00       0.078598
# 218 2023-03-16 12:00:00       0.082472
#
# [219 rows x 2 columns]

# %%
plt.figure(figsize=(10, 6))  # optional; specifies the size of the figure
plt.plot(df['date'], df['lwe_thickness'], marker='o')  # creates a line plot with markers at each data point

plt.xlabel('Date')
plt.ylabel('LWE Thickness (m)')
plt.title('GRACE and GRACE-FO: LWE Thickness Over Time')

plt.xticks(rotation=45)

# Set x-axis major locator to be each year
plt.gca().xaxis.set_major_locator(mdates.YearLocator())

# Set x-axis major formatter to display only the year
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

plt.grid(True)  # optional; adds a grid for easier visualization
plt.show()

# %%
df_grace = xr.open_dataset('~/remoteData/GRACE_NEW/data/TELLUS_GRAC_L3_CSR_RL06_LND_v04/GRD-3_2017143-2017179_GRAC_UTCSR_BA01_0600_LND_v04.nc')

# %%
df_grace
# Out:
# <xarray.Dataset>
# Dimensions:        (lon: 360, lat: 180, time: 1, bounds: 2)
# Coordinates:
#   * lon            (lon) float64 0.5 1.5 2.5 3.5 4.5 ... 356.5 357.5 358.5 359.5
#   * lat            (lat) float64 -89.5 -88.5 -87.5 -86.5 ... 86.5 87.5 88.5 89.5
#   * time           (time) datetime64[ns] 2017-06-10T12:00:00
# Dimensions without coordinates: bounds
# Data variables:
#     lwe_thickness  (time, lat, lon) float64 ...
#     uncertainty    (time, lat, lon) float64 ...
#     lat_bounds     (lat, bounds) float64 ...
#     lon_bounds     (lon, bounds) float64 ...
#     time_bounds    (time, bounds) datetime64[ns] ...
# Attributes: (12/59)
#     Conventions:                CF-1.6
#     standard_name_vocabulary:   NetCDF Climate and Forecast (CF) Metadata Con...
#     title:                      GRACE-FO Water-Equivalent-Thickness Surface-M...
#     id:                         TELND-3NC64
#     summary:                    Gridded surface mass anomalies, derived from ...
#     processing_level:           3
#     ...                         ...
#     geospatial_lat_units:       degrees_north
#     geospatial_lat_resolution:  One degree grid
#     geospatial_lon_min:         0.5
#     geospatial_lon_max:         359.5
#     geospatial_lon_units:       degrees_east
#     geospatial_lon_resolution:  One degree grid

# %%
print(df_grace['lat_bounds'].values)
# Out:
# [[-9.00000000e+01 -8.90000000e+01]
#  [-8.90000000e+01 -8.80000000e+01]
#  [-8.80000000e+01 -8.70000000e+01]
#  [-8.70000000e+01 -8.60000000e+01]
#  [-8.60000000e+01 -8.50000000e+01]
#  [-8.50000000e+01 -8.40000000e+01]
#  [-8.40000000e+01 -8.30000000e+01]
#  [-8.30000000e+01 -8.20000000e+01]
#  [-8.20000000e+01 -8.10000000e+01]
#  [-8.10000000e+01 -8.00000000e+01]
#  [-8.00000000e+01 -7.90000000e+01]
#  [-7.90000000e+01 -7.80000000e+01]
#  [-7.80000000e+01 -7.70000000e+01]
#  [-7.70000000e+01 -7.60000000e+01]
#  [-7.60000000e+01 -7.50000000e+01]
#  [-7.50000000e+01 -7.40000000e+01]
#  [-7.40000000e+01 -7.30000000e+01]
#  [-7.30000000e+01 -7.20000000e+01]
#  [-7.20000000e+01 -7.10000000e+01]
#  [-7.10000000e+01 -7.00000000e+01]
#  [-7.00000000e+01 -6.90000000e+01]
#  [-6.90000000e+01 -6.80000000e+01]
#  [-6.80000000e+01 -6.70000000e+01]
#  [-6.70000000e+01 -6.60000000e+01]
#  [-6.60000000e+01 -6.50000000e+01]
#  [-6.50000000e+01 -6.40000000e+01]
#  [-6.40000000e+01 -6.30000000e+01]
#  [-6.30000000e+01 -6.20000000e+01]
#  [-6.20000000e+01 -6.10000000e+01]
#  [-6.10000000e+01 -6.00000000e+01]
#  [-6.00000000e+01 -5.90000000e+01]
#  [-5.90000000e+01 -5.80000000e+01]
#  [-5.80000000e+01 -5.70000000e+01]
#  [-5.70000000e+01 -5.60000000e+01]
#  [-5.60000000e+01 -5.50000000e+01]
#  [-5.50000000e+01 -5.40000000e+01]
#  [-5.40000000e+01 -5.30000000e+01]
#  [-5.30000000e+01 -5.20000000e+01]
#  [-5.20000000e+01 -5.10000000e+01]
#  [-5.10000000e+01 -5.00000000e+01]
#  [-5.00000000e+01 -4.90000000e+01]
#  [-4.90000000e+01 -4.80000000e+01]
#  [-4.80000000e+01 -4.70000000e+01]
#  [-4.70000000e+01 -4.60000000e+01]
#  [-4.60000000e+01 -4.50000000e+01]
#  [-4.50000000e+01 -4.40000000e+01]
#  [-4.40000000e+01 -4.30000000e+01]
#  [-4.30000000e+01 -4.20000000e+01]
#  [-4.20000000e+01 -4.10000000e+01]
#  [-4.10000000e+01 -4.00000000e+01]
#  [-4.00000000e+01 -3.90000000e+01]
#  [-3.90000000e+01 -3.80000000e+01]
#  [-3.80000000e+01 -3.70000000e+01]
#  [-3.70000000e+01 -3.60000000e+01]
#  [-3.60000000e+01 -3.50000000e+01]
#  [-3.50000000e+01 -3.40000000e+01]
#  [-3.40000000e+01 -3.30000000e+01]
#  [-3.30000000e+01 -3.20000000e+01]
#  [-3.20000000e+01 -3.10000000e+01]
#  [-3.10000000e+01 -3.00000000e+01]
#  [-3.00000000e+01 -2.90000000e+01]
#  [-2.90000000e+01 -2.80000000e+01]
#  [-2.80000000e+01 -2.70000000e+01]
#  [-2.70000000e+01 -2.60000000e+01]
#  [-2.60000000e+01 -2.50000000e+01]
#  [-2.50000000e+01 -2.40000000e+01]
#  [-2.40000000e+01 -2.30000000e+01]
#  [-2.30000000e+01 -2.20000000e+01]
#  [-2.20000000e+01 -2.10000000e+01]
#  [-2.10000000e+01 -2.00000000e+01]
#  [-2.00000000e+01 -1.90000000e+01]
#  [-1.90000000e+01 -1.80000000e+01]
#  [-1.80000000e+01 -1.70000000e+01]
#  [-1.70000000e+01 -1.60000000e+01]
#  [-1.60000000e+01 -1.50000000e+01]
#  [-1.50000000e+01 -1.40000000e+01]
#  [-1.40000000e+01 -1.30000000e+01]
#  [-1.30000000e+01 -1.20000000e+01]
#  [-1.20000000e+01 -1.10000000e+01]
#  [-1.10000000e+01 -1.00000000e+01]
#  [-1.00000000e+01 -9.00000000e+00]
#  [-9.00000000e+00 -8.00000000e+00]
#  [-8.00000000e+00 -7.00000000e+00]
#  [-7.00000000e+00 -6.00000000e+00]
#  [-6.00000000e+00 -5.00000000e+00]
#  [-5.00000000e+00 -4.00000000e+00]
#  [-4.00000000e+00 -3.00000000e+00]
#  [-3.00000000e+00 -2.00000000e+00]
#  [-2.00000000e+00 -1.00000000e+00]
#  [-1.00000000e+00  1.42108547e-14]
#  [ 1.42108547e-14  1.00000000e+00]
#  [ 1.00000000e+00  2.00000000e+00]
#  [ 2.00000000e+00  3.00000000e+00]
#  [ 3.00000000e+00  4.00000000e+00]
#  [ 4.00000000e+00  5.00000000e+00]
#  [ 5.00000000e+00  6.00000000e+00]
#  [ 6.00000000e+00  7.00000000e+00]
#  [ 7.00000000e+00  8.00000000e+00]
#  [ 8.00000000e+00  9.00000000e+00]
#  [ 9.00000000e+00  1.00000000e+01]
#  [ 1.00000000e+01  1.10000000e+01]
#  [ 1.10000000e+01  1.20000000e+01]
#  [ 1.20000000e+01  1.30000000e+01]
#  [ 1.30000000e+01  1.40000000e+01]
#  [ 1.40000000e+01  1.50000000e+01]
#  [ 1.50000000e+01  1.60000000e+01]
#  [ 1.60000000e+01  1.70000000e+01]
#  [ 1.70000000e+01  1.80000000e+01]
#  [ 1.80000000e+01  1.90000000e+01]
#  [ 1.90000000e+01  2.00000000e+01]
#  [ 2.00000000e+01  2.10000000e+01]
#  [ 2.10000000e+01  2.20000000e+01]
#  [ 2.20000000e+01  2.30000000e+01]
#  [ 2.30000000e+01  2.40000000e+01]
#  [ 2.40000000e+01  2.50000000e+01]
#  [ 2.50000000e+01  2.60000000e+01]
#  [ 2.60000000e+01  2.70000000e+01]
#  [ 2.70000000e+01  2.80000000e+01]
#  [ 2.80000000e+01  2.90000000e+01]
#  [ 2.90000000e+01  3.00000000e+01]
#  [ 3.00000000e+01  3.10000000e+01]
#  [ 3.10000000e+01  3.20000000e+01]
#  [ 3.20000000e+01  3.30000000e+01]
#  [ 3.30000000e+01  3.40000000e+01]
#  [ 3.40000000e+01  3.50000000e+01]
#  [ 3.50000000e+01  3.60000000e+01]
#  [ 3.60000000e+01  3.70000000e+01]
#  [ 3.70000000e+01  3.80000000e+01]
#  [ 3.80000000e+01  3.90000000e+01]
#  [ 3.90000000e+01  4.00000000e+01]
#  [ 4.00000000e+01  4.10000000e+01]
#  [ 4.10000000e+01  4.20000000e+01]
#  [ 4.20000000e+01  4.30000000e+01]
#  [ 4.30000000e+01  4.40000000e+01]
#  [ 4.40000000e+01  4.50000000e+01]
#  [ 4.50000000e+01  4.60000000e+01]
#  [ 4.60000000e+01  4.70000000e+01]
#  [ 4.70000000e+01  4.80000000e+01]
#  [ 4.80000000e+01  4.90000000e+01]
#  [ 4.90000000e+01  5.00000000e+01]
#  [ 5.00000000e+01  5.10000000e+01]
#  [ 5.10000000e+01  5.20000000e+01]
#  [ 5.20000000e+01  5.30000000e+01]
#  [ 5.30000000e+01  5.40000000e+01]
#  [ 5.40000000e+01  5.50000000e+01]
#  [ 5.50000000e+01  5.60000000e+01]
#  [ 5.60000000e+01  5.70000000e+01]
#  [ 5.70000000e+01  5.80000000e+01]
#  [ 5.80000000e+01  5.90000000e+01]
#  [ 5.90000000e+01  6.00000000e+01]
#  [ 6.00000000e+01  6.10000000e+01]
#  [ 6.10000000e+01  6.20000000e+01]
#  [ 6.20000000e+01  6.30000000e+01]
#  [ 6.30000000e+01  6.40000000e+01]
#  [ 6.40000000e+01  6.50000000e+01]
#  [ 6.50000000e+01  6.60000000e+01]
#  [ 6.60000000e+01  6.70000000e+01]
#  [ 6.70000000e+01  6.80000000e+01]
#  [ 6.80000000e+01  6.90000000e+01]
#  [ 6.90000000e+01  7.00000000e+01]
#  [ 7.00000000e+01  7.10000000e+01]
#  [ 7.10000000e+01  7.20000000e+01]
#  [ 7.20000000e+01  7.30000000e+01]
#  [ 7.30000000e+01  7.40000000e+01]
#  [ 7.40000000e+01  7.50000000e+01]
#  [ 7.50000000e+01  7.60000000e+01]
#  [ 7.60000000e+01  7.70000000e+01]
#  [ 7.70000000e+01  7.80000000e+01]
#  [ 7.80000000e+01  7.90000000e+01]
#  [ 7.90000000e+01  8.00000000e+01]
#  [ 8.00000000e+01  8.10000000e+01]
#  [ 8.10000000e+01  8.20000000e+01]
#  [ 8.20000000e+01  8.30000000e+01]
#  [ 8.30000000e+01  8.40000000e+01]
#  [ 8.40000000e+01  8.50000000e+01]
#  [ 8.50000000e+01  8.60000000e+01]
#  [ 8.60000000e+01  8.70000000e+01]
#  [ 8.70000000e+01  8.80000000e+01]
#  [ 8.80000000e+01  8.90000000e+01]
#  [ 8.90000000e+01  9.00000000e+01]]

# %%
print(df_grace['lat_bounds'].coords)
# Out:
# Coordinates:
#   * lat      (lat) float64 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5

# %%
df_grace['lat_bounds'].sel(lat=-89.5).values
# Out:
# array([-90., -89.])

# %%
print(df_grace['lwe_thickness'].dims)
# Out:
# ('time', 'lat', 'lon')

# %% [markdown]
# lat: 30N-40N, lon: 90W-80W (-90to-80)
#
# lat: 30-40, lon:270-280

# %%
df_grace['lwe_thickness'].sel(lat=slice(30.5, 39.5), lon=slice(270.5, 279.5)).mean().values.item()
# Out:
# 0.06678245512623972
